# %%
import pandas as pd

# %%
var1 = pd.read_csv("C:\\Users\\vishal\\Marks.csv")

# %%
var1
# Out:
#      Student  English  Hindi coding language       city    Country  Age
# 0    rakesh        50     49             php   New york    America   20
# 1      mohan       70     39          python     London         UK   31
# 2    harshit       40     30            java     Huston         UK   32
# 3     Bharti       40     70      javascript      Delhi      India   34
# 4     akaskh       40     53             php   Melborne  Australia   45
# 5      mohit       70     48          python   Benglore      India   34
# 6       joan       30     29             c++        NaN        NaN   32
# 7       jack       40     54            Ruby      Texas    America   21
# 8       adam       45     67            html  las vegas    America   34
# 9       kyle       65     78            html      mosco     Russia   27
# 10      axar       73     37            java     moraco        NaN   28
# 11  kuldeep        90     80            java      wales         UK   32
# ...

# %%
var2 = var1.dropna()

# %%
var2
# Out:
#      Student  English  Hindi coding language       city    Country  Age
# 0    rakesh        50     49             php   New york    America   20
# 1      mohan       70     39          python     London         UK   31
# 2    harshit       40     30            java     Huston         UK   32
# 3     Bharti       40     70      javascript      Delhi      India   34
# 4     akaskh       40     53             php   Melborne  Australia   45
# 5      mohit       70     48          python   Benglore      India   34
# 7       jack       40     54            Ruby      Texas    America   21
# 8       adam       45     67            html  las vegas    America   34
# 9       kyle       65     78            html      mosco     Russia   27
# 11  kuldeep        90     80            java      wales         UK   32
# 12  abhishek       92     32          python  hong kong  hong kong   34
# 13    sammer       83     89          python    Kolkata      India   57
# ...

# %%
var3 = var1.dropna(axis=1)

# %%
var3
# Out:
#      Student  English  Hindi coding language  Age
# 0    rakesh        50     49             php   20
# 1      mohan       70     39          python   31
# 2    harshit       40     30            java   32
# 3     Bharti       40     70      javascript   34
# 4     akaskh       40     53             php   45
# 5      mohit       70     48          python   34
# 6       joan       30     29             c++   32
# 7       jack       40     54            Ruby   21
# 8       adam       45     67            html   34
# 9       kyle       65     78            html   27
# 10      axar       73     37            java   28
# 11  kuldeep        90     80            java   32
# 12  abhishek       92     32          python   34
# 13    sammer       83     89          python   57
# 14     mohan       38     90             c++   25
# 15     rohan       40     50            html   24
# 16     divya       70     49            html   23
# 17    deppti       82     32          python   22
# ...

# %%
var4 = var1.dropna(axis=0)

# %%
var4
# Out:
#      Student  English  Hindi coding language       city    Country  Age
# 0    rakesh        50     49             php   New york    America   20
# 1      mohan       70     39          python     London         UK   31
# 2    harshit       40     30            java     Huston         UK   32
# 3     Bharti       40     70      javascript      Delhi      India   34
# 4     akaskh       40     53             php   Melborne  Australia   45
# 5      mohit       70     48          python   Benglore      India   34
# 7       jack       40     54            Ruby      Texas    America   21
# 8       adam       45     67            html  las vegas    America   34
# 9       kyle       65     78            html      mosco     Russia   27
# 11  kuldeep        90     80            java      wales         UK   32
# 12  abhishek       92     32          python  hong kong  hong kong   34
# 13    sammer       83     89          python    Kolkata      India   57
# ...

# %%
var5 = var1.dropna(how="any")

# %%
var5
# Out:
#      Student  English  Hindi coding language       city    Country  Age
# 0    rakesh        50     49             php   New york    America   20
# 1      mohan       70     39          python     London         UK   31
# 2    harshit       40     30            java     Huston         UK   32
# 3     Bharti       40     70      javascript      Delhi      India   34
# 4     akaskh       40     53             php   Melborne  Australia   45
# 5      mohit       70     48          python   Benglore      India   34
# 7       jack       40     54            Ruby      Texas    America   21
# 8       adam       45     67            html  las vegas    America   34
# 9       kyle       65     78            html      mosco     Russia   27
# 11  kuldeep        90     80            java      wales         UK   32
# 12  abhishek       92     32          python  hong kong  hong kong   34
# 13    sammer       83     89          python    Kolkata      India   57
# ...

# %%
var6 = var1.dropna(how="all")

# %%
var6
# Out:
#      Student  English  Hindi coding language       city    Country  Age
# 0    rakesh        50     49             php   New york    America   20
# 1      mohan       70     39          python     London         UK   31
# 2    harshit       40     30            java     Huston         UK   32
# 3     Bharti       40     70      javascript      Delhi      India   34
# 4     akaskh       40     53             php   Melborne  Australia   45
# 5      mohit       70     48          python   Benglore      India   34
# 6       joan       30     29             c++        NaN        NaN   32
# 7       jack       40     54            Ruby      Texas    America   21
# 8       adam       45     67            html  las vegas    America   34
# 9       kyle       65     78            html      mosco     Russia   27
# 10      axar       73     37            java     moraco        NaN   28
# 11  kuldeep        90     80            java      wales         UK   32
# ...

# %%
var7 = var1.dropna(subset=['Country'])

# %%
var7
# Out:
#      Student  English  Hindi coding language       city    Country  Age
# 0    rakesh        50     49             php   New york    America   20
# 1      mohan       70     39          python     London         UK   31
# 2    harshit       40     30            java     Huston         UK   32
# 3     Bharti       40     70      javascript      Delhi      India   34
# 4     akaskh       40     53             php   Melborne  Australia   45
# 5      mohit       70     48          python   Benglore      India   34
# 7       jack       40     54            Ruby      Texas    America   21
# 8       adam       45     67            html  las vegas    America   34
# 9       kyle       65     78            html      mosco     Russia   27
# 11  kuldeep        90     80            java      wales         UK   32
# 12  abhishek       92     32          python  hong kong  hong kong   34
# 13    sammer       83     89          python    Kolkata      India   57
# ...

# %%
var8 = var1.dropna(thresh=2)

# %%
var8
# Out:
#      Student  English  Hindi coding language       city    Country  Age
# 0    rakesh        50     49             php   New york    America   20
# 1      mohan       70     39          python     London         UK   31
# 2    harshit       40     30            java     Huston         UK   32
# 3     Bharti       40     70      javascript      Delhi      India   34
# 4     akaskh       40     53             php   Melborne  Australia   45
# 5      mohit       70     48          python   Benglore      India   34
# 6       joan       30     29             c++        NaN        NaN   32
# 7       jack       40     54            Ruby      Texas    America   21
# 8       adam       45     67            html  las vegas    America   34
# 9       kyle       65     78            html      mosco     Russia   27
# 10      axar       73     37            java     moraco        NaN   28
# 11  kuldeep        90     80            java      wales         UK   32
# ...

# %%
var9 = var1.fillna("chh")

# %%
var9
# Out:
#      Student  English  Hindi coding language       city    Country  Age
# 0    rakesh        50     49             php   New york    America   20
# 1      mohan       70     39          python     London         UK   31
# 2    harshit       40     30            java     Huston         UK   32
# 3     Bharti       40     70      javascript      Delhi      India   34
# 4     akaskh       40     53             php   Melborne  Australia   45
# 5      mohit       70     48          python   Benglore      India   34
# 6       joan       30     29             c++        chh        chh   32
# 7       jack       40     54            Ruby      Texas    America   21
# 8       adam       45     67            html  las vegas    America   34
# 9       kyle       65     78            html      mosco     Russia   27
# 10      axar       73     37            java     moraco        chh   28
# 11  kuldeep        90     80            java      wales         UK   32
# ...

# %%
var10= var1.fillna({"Country":"cy","city":"jy"})

# %%
var10
# Out:
#      Student  English  Hindi coding language       city    Country  Age
# 0    rakesh        50     49             php   New york    America   20
# 1      mohan       70     39          python     London         UK   31
# 2    harshit       40     30            java     Huston         UK   32
# 3     Bharti       40     70      javascript      Delhi      India   34
# 4     akaskh       40     53             php   Melborne  Australia   45
# 5      mohit       70     48          python   Benglore      India   34
# 6       joan       30     29             c++         jy         cy   32
# 7       jack       40     54            Ruby      Texas    America   21
# 8       adam       45     67            html  las vegas    America   34
# 9       kyle       65     78            html      mosco     Russia   27
# 10      axar       73     37            java     moraco         cy   28
# 11  kuldeep        90     80            java      wales         UK   32
# ...

# %%
var11= var1.fillna(method="ffill",axis=0)

# %%
var11
# Out:
#      Student  English  Hindi coding language       city    Country  Age
# 0    rakesh        50     49             php   New york    America   20
# 1      mohan       70     39          python     London         UK   31
# 2    harshit       40     30            java     Huston         UK   32
# 3     Bharti       40     70      javascript      Delhi      India   34
# 4     akaskh       40     53             php   Melborne  Australia   45
# 5      mohit       70     48          python   Benglore      India   34
# 6       joan       30     29             c++   Benglore      India   32
# 7       jack       40     54            Ruby      Texas    America   21
# 8       adam       45     67            html  las vegas    America   34
# 9       kyle       65     78            html      mosco     Russia   27
# 10      axar       73     37            java     moraco     Russia   28
# 11  kuldeep        90     80            java      wales         UK   32
# ...

# %%
var12 = var1.fillna(method ="bfill")

# %%
var12
# Out:
#      Student  English  Hindi coding language       city    Country  Age
# 0    rakesh        50     49             php   New york    America   20
# 1      mohan       70     39          python     London         UK   31
# 2    harshit       40     30            java     Huston         UK   32
# 3     Bharti       40     70      javascript      Delhi      India   34
# 4     akaskh       40     53             php   Melborne  Australia   45
# 5      mohit       70     48          python   Benglore      India   34
# 6       joan       30     29             c++      Texas    America   32
# 7       jack       40     54            Ruby      Texas    America   21
# 8       adam       45     67            html  las vegas    America   34
# 9       kyle       65     78            html      mosco     Russia   27
# 10      axar       73     37            java     moraco         UK   28
# 11  kuldeep        90     80            java      wales         UK   32
# ...

# %%
var13 = var1.fillna(12,inplace=True)

# %%
var13

# %%
var14 = var1.fillna('jj',limit=2)

# %%
var14
# Out:
#      Student  English  Hindi coding language       city    Country  Age
# 0    rakesh        50     49             php   New york    America   20
# 1      mohan       70     39          python     London         UK   31
# 2    harshit       40     30            java     Huston         UK   32
# 3     Bharti       40     70      javascript      Delhi      India   34
# 4     akaskh       40     53             php   Melborne  Australia   45
# 5      mohit       70     48          python   Benglore      India   34
# 6       joan       30     29             c++         jj         jj   32
# 7       jack       40     54            Ruby      Texas    America   21
# 8       adam       45     67            html  las vegas    America   34
# 9       kyle       65     78            html      mosco     Russia   27
# 10      axar       73     37            java     moraco         jj   28
# 11  kuldeep        90     80            java      wales         UK   32
# ...

# %%
# Out:
#      Student  English  Hindi coding language       city    Country  Age
# 0    rakesh        50     49             php   New york    America   20
# 1      mohan       70     39          python     London         UK   31
# 2    harshit       40     30            java     Huston         UK   32
# 3     Bharti       40     70      javascript      Delhi      India   34
# 4     akaskh       40     53             php   Melborne  Australia   45
# 5      mohit       70     48          python   Benglore      India   34
# 6       joan       30     29             c++         jj         jj   32
# 7       jack       40     54            Ruby      Texas    America   21
# 8       adam       45     67            html  las vegas    America   34
# 9       kyle       65     78            html      mosco     Russia   27
# 10      axar       73     37            java     moraco         jj   28
# 11  kuldeep        90     80            java      wales         UK   32
# ...
