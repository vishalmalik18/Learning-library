# %%
import pandas as pd

# %%
var = pd.read_csv("C:\\Users\\vishal\\Marks.csv",index_col=0)

# %%
var
# Out:
#               Maths Programming languages  English marks  Hindi marks  \
# Student
# Mohan            70                   C++           70.0         75.0
# Rakesh           40                python           45.0         45.0
# Vishal           50                  java           80.0         80.0
# Rockey           40                  ruby            NaN          NaN
# shivashi         30                  java           80.0         70.0
# Mukesh           40          java scripit           70.0         48.0
# Axar             70                python           90.0          NaN
# kuldeep          50                  html           50.0         50.0
# jadeja           40                    C+           60.0         70.0
# sunil            30                   CSS           50.0         40.0
# Ravi shastri     40                   CSS           40.0         45.0
#
#                              gmail id      City  Unnamed: 7
# Student
# ...

# %%
var1= var.drop(var.filter(regex="Unnamed"),axis=1,inplace=True)

# %%
var1

# %%
var
# Out:
#               Maths Programming languages  English marks  Hindi marks  \
# Student
# Mohan            70                   C++           70.0         75.0
# Rakesh           40                python           45.0         45.0
# Vishal           50                  java           80.0         80.0
# Rockey           40                  ruby            NaN          NaN
# shivashi         30                  java           80.0         70.0
# Mukesh           40          java scripit           70.0         48.0
# Axar             70                python           90.0          NaN
# kuldeep          50                  html           50.0         50.0
# jadeja           40                    C+           60.0         70.0
# sunil            30                   CSS           50.0         40.0
# Ravi shastri     40                   CSS           40.0         45.0
#
#                              gmail id      City
# Student
# Mohan               Mohan01@gmail.com    Bostin
# ...

# %%
var.dropna(how="all")
# Out:
#          Student  Maths Programming languages  English marks  Hindi marks  \
# 0          Mohan     70                   C++           70.0         75.0
# 1         Rakesh     40                python           45.0         45.0
# 2         Vishal     50                  java           80.0         80.0
# 3         Rockey     40                  ruby            NaN          NaN
# 4       shivashi     30                  java           80.0         70.0
# 5         Mukesh     40          java scripit           70.0         48.0
# 6           Axar     70                python           90.0          NaN
# 7        kuldeep     50                  html           50.0         50.0
# 8         jadeja     40                    C+           60.0         70.0
# 9          sunil     30                   CSS           50.0         40.0
# 10  Ravi shastri     40                   CSS           40.0         45.0
#
#                    gmail id      City  Unnamed: 7
# ...
