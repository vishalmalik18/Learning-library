# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
var = sns.load_dataset("tips")

# %%
var
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
var2 = sns.load_dataset("tips").head(20)

# %%
var2
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 0        16.99  1.01  Female     No  Sun  Dinner     2
# 1        10.34  1.66    Male     No  Sun  Dinner     3
# 2        21.01  3.50    Male     No  Sun  Dinner     3
# 3        23.68  3.31    Male     No  Sun  Dinner     2
# 4        24.59  3.61  Female     No  Sun  Dinner     4
# 5        25.29  4.71    Male     No  Sun  Dinner     4
# 6         8.77  2.00    Male     No  Sun  Dinner     2
# 7        26.88  3.12    Male     No  Sun  Dinner     4
# 8        15.04  1.96    Male     No  Sun  Dinner     2
# 9        14.78  3.23    Male     No  Sun  Dinner     2
# 10       10.27  1.71    Male     No  Sun  Dinner     2
# 11       35.26  5.00  Female     No  Sun  Dinner     4
# 12       15.42  1.57    Male     No  Sun  Dinner     2
# 13       18.43  3.00    Male     No  Sun  Dinner     4
# 14       14.83  3.02  Female     No  Sun  Dinner     2
# 15       21.58  3.92    Male     No  Sun  Dinner     2
# ...

# %%
sns.pointplot(x="size",y="tip",data=var,hue="sex")
plt.show()

# %%
sns.pointplot(x="size",y="tip",data=var2,hue="sex")
plt.show()

# %%
sns.catplot(x="size",y="tip",data=var2,hue="sex",kind="point")
plt.show()

# %%
sns.catplot(x="size",y="tip",data=var2,
            hue ="sex",palette="Oranges",kind="strip")
plt.show()

# %%
sns.catplot(x="size",y="tip",data=var2,
            hue="sex",palette="BuGn",kind="point")
plt.show()

# %%
sns.catplot(x="day",y="total_bill",data=var,hue="sex",palette="Oranges"
            ,height=3,kind="point")
plt.show()

# %%
sns.catplot(x="day",y="total_bill",data=var,hue=
            "sex",kind="box",height=5,showmeans=True,
            meanprops={"marker":"+","markeredgecolor":"g"})
plt.show()

# %%
sns.catplot(y="day",x="total_bill",data=var,hue=
            "sex",kind="box",height=5,showmeans=True,
            meanprops={"marker":"+","markeredgecolor":"g"})
plt.show()

# %%
sns.catplot(x="day",y="total_bill",data=var,hue=
            "sex",kind="box",height=10,showmeans=True,
            meanprops={"marker":"+","markeredgecolor":"g"})
plt.show()

# %%
sns.catplot(x="day",y="total_bill",data=var,hue=
            "sex",kind="boxen")
plt.show()

# %%
sns.catplot(x="size",y="tip",data=var,hue=
            "sex",kind="count")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 sns.catplot(x="size",y="tip",data=var,hue=
#       2             "sex",kind="count")
#       3 plt.show()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3171, in catplot(data, x, y, hue, row, col, col_wrap, estimator, errorbar, n_boot, units, seed, order, hue_order, row_order, col_order, height, aspect, kind, native_scale, formatter, orient, color, palette, hue_norm, legend, legend_out, sharex, sharey, margin_titles, facet_kws, ci, **kwargs)
#    3169         x_, y_, orient = x, x, "v"
#    3170     else:
# -> 3171         raise ValueError("Either `x` or `y` must be None for kind='count'")
#    3172 else:
#    3173     x_, y_ = x, y
#
# ValueError: Either `x` or `y` must be None for kind='count'
