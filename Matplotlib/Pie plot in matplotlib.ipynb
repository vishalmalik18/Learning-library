# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = [10,20,30,40]
y = ["c++","c+","java","python"]
plt.pie(x,labels=y)
plt.show()

# %%
x = [10,20,30,40]
y = ["c++","c+","java","python"]
ex = [0.2,0.0,0.0,0.0]
plt.pie(x,labels=y,explode=ex)
plt.show()

# %%
x = [10,20,30,40]
y = ["c++","c+","java","python"]
ex = [0.2,0.0,0.0,0.0]
plt.pie(x,labels=y,explode=ex,autopct = "%0.1f%%")
plt.show()

# %%
x = [10,20,30,40]
y = ["c++","c+","java","python"]
ex = [0.2,0.0,0.0,0.0]
plt.pie(x,labels=y,explode=ex,autopct = "%0.2f%%")
plt.show()

# %%
x = [10,20,30,40]
y = ["c++","c+","java","python"]
ex = [0.2,0.0,0.0,0.0]
plt.pie(x,labels=y,explode=ex,autopct = "%0.2f%%",shadow=True)
plt.show()

# %%
x = [10,20,30,40]
y = ["c++","c+","java","python"]
ex = [0.2,0.0,0.0,0.0]
plt.pie(x,labels=y,explode=ex,autopct = "%0.2f%%",shadow=True,radius=0.8)
plt.show()

# %%
x = [10,20,30,40]
y = ["c++","c+","java","python"]
ex = [0.2,0.0,0.0,0.0]
plt.pie(x,labels=y,explode=ex,autopct = "%0.2f%%",shadow =True,labeldistance=1.1)
plt.show()

# %%
x = [10,20,30,40]
y = ["c++","c+","java","python"]
ex = [0.0,0.0,0.0,0.1]
plt.pie(x,labels=y,explode=ex,autopct = "%0.2f%%",startangle=90,shadow =True)
plt.show()

# %%
x = [10,20,30,40]
y = ["c++","c+","java","python"]
ex = [0.0,0.0,0.0,0.1]
plt.pie(x,labels=y,explode=ex,autopct = "%0.1f%%",startangle=90,shadow=True,
       textprops={"fontsize":11,"fontcolor":"r"})
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[49], line 4
#       2 y = ["c++","c+","java","python"]
#       3 ex = [0.0,0.0,0.0,0.1]
# ----> 4 plt.pie(x,labels=y,explode=ex,autopct = "%0.1f%%",startangle=90,shadow=True,
#       5        textprops={"fontsize":11,"fontcolor":"r"})
#       6 plt.show()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\pyplot.py:2799, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch, data)
#    2792 @_copy_docstring_and_deprecators(Axes.pie)
#    2793 def pie(
#    2794         x, explode=None, labels=None, colors=None, autopct=None,
#    (...)
#    2797         textprops=None, center=(0, 0), frame=False,
# ...

# %%
x = [10,20,30,40]
y = ["c++","c+","java","python"]
ex = [0.0,0.0,0.0,0.1]
plt.pie(x,labels=y,explode=ex,autopct = "%0.1f%%",shadow = True,
        startangle=90)
plt.show()

# %%
x = [10,20,30,40]
y = ["c++","c+","java","python"]
ex = [0.0,0.0,0.0,0.1]
plt.pie(x,labels=y,explode=ex,autopct = "%0.1f%%",shadow = True,
        startangle=90,wedgeprops={"linewidth":7})
plt.show()

# %%
x = [10,20,30,40]
y = ["c++","c+","java","python"]
ex = [0.0,0.0,0.0,0.1]
plt.pie(x,labels=y,explode=ex,autopct = "%0.1f%%",shadow = True,
        startangle=90,wedgeprops={"linewidth":7,"width":1})
plt.show()

# %%
x = [10,20,30,40]
y = ["c++","c+","java","python"]
ex = [0.0,0.0,0.0,0.1]
plt.pie(x,labels=y,explode=ex,autopct = "%0.1f%%",shadow = True,
        startangle=90,wedgeprops={"linewidth":7,"edgecolor":"m"})
plt.show()

# %%
x = [10,20,30,40]
y = ["c++","c+","java","python"]
ex = [0.0,0.0,0.0,0.1]
plt.pie(x,labels=y,explode=ex,autopct = "%0.1f%%",shadow = True,
        startangle=90,wedgeprops={"linewidth":7}
        ,center=(3,0))
plt.show()

# %%
x = [10,20,30,40]
y = ["c++","c+","java","python"]
ex = [0.0,0.0,0.0,0.1]
plt.pie(x,labels=y,explode=ex,autopct = "%0.1f%%",shadow = True,
        startangle=90,wedgeprops={"linewidth":7},rotatelabels=True)
plt.show()

# %%
x = [10,20,30,40]
y = ["c++","c+","java","python"]
ex = [0.0,0.0,0.0,0.1]
plt.pie(x,labels=y,explode=ex,autopct = "%0.1f%%",shadow = True,
        startangle=90,wedgeprops={"linewidth":7})
plt.title("Data")
plt.legend()
plt.show()

# %%
x = [10,20,30,40]
y = ["c++","c+","java","python"]
ex = [0.0,0.0,0.0,0.1]
plt.pie(x,labels=y,explode=ex,autopct = "%0.1f%%",shadow = True,
        startangle=90,wedgeprops={"linewidth":7})
plt.title("Data")
plt.legend(loc=2)
plt.show()

# %%
y = ["python"]
plt.pie([1],labels=y)
plt.title("Data")
plt.legend()
plt.show()

# %%
x = [10,20,30,40]
x1 = [40,30,20,10]
y = ["c+","c++","java","python"]
c = ["r","b","g","y"]

plt.pie(x,labels=y,radius=1.5)
plt.pie(x1,radius=1,colors=c)
plt.show()

# %%
x = [10,20,30,40]
x1 = [40,30,20,10]
y = ["c+","c++","java","python"]
plt.pie(x,labels=y,radius=1.5)
plt.pie(x1,radius=0.5)
plt.show()

# %%
cx = [10,20,30,40]
x1 = [1]
y = ["c+","c++","java","python"]

plt.pie(x,labels=y,radius=1.5,)
plt.pie(x1,colors="w")
plt.show()

# %%
cx = [10,20,30,40]
x1 = [40,30,20,10]
y = ["c+","c++","java","python"]

plt.pie(x,labels=y,radius=1.5,)
cr = plt.Circle(xy=(0,0),radius=1,facecolor="w")
plt.gca().add_artist(cr)
plt.show()
